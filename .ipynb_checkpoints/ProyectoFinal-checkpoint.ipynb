# %%
import pandas as pd
import json
from pandas import json_normalize

# %%
# Load JSON
f = open('./mpd.slice.0-999.json')  
data = json.load(f)
f.close()

# %%
# Convert playlists array to df
df = pd.DataFrame(data['playlists'])
df.head()
# Out:
#                name collaborative  pid  modified_at  num_tracks  num_albums  \
# 0        Throwbacks         false    0   1493424000          52          47
# 1  Awesome Playlist         false    1   1506556800          39          23
# 2           korean          false    2   1505692800          64          51
# 3               mat         false    3   1501027200         126         107
# 4               90s         false    4   1401667200          17          16
#
#    num_followers                                             tracks  \
# 0              1  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1              1  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2              1  [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3              1  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4              2  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...
#
#    num_edits  duration_ms  num_artists
# 0          6     11532414           37
# 1          5     11656470           21
# 2         18     14039958           31
# 3          4     28926058           86
# 4          7      4335282           16

# %%
# Clean unnecessary columns
df_cleaned = df.filter(['name','tracks'], axis=1)
df_cleaned.head()
# Out:
#                name                                             tracks
# 0        Throwbacks  [{'pos': 0, 'artist_name': 'Missy Elliott', 't...
# 1  Awesome Playlist  [{'pos': 0, 'artist_name': 'Survivor', 'track_...
# 2           korean   [{'pos': 0, 'artist_name': 'Hoody', 'track_uri...
# 3               mat  [{'pos': 0, 'artist_name': 'Camille Saint-Saën...
# 4               90s  [{'pos': 0, 'artist_name': 'The Smashing Pumpk...

# %%
# Create final df with nested track's array in each playlist
df_final = pd.DataFrame()
for i in range(0, len(data['playlists'])):
    df_nested_list = pd.json_normalize(
        data['playlists'][i], 
        record_path =['tracks'],
        meta=['name']
    )
    df_cleaned2 = df_nested_list.filter(['name','album_name','track_name','artist_name'], axis=1)
    df_final = pd.concat([df_final, df_cleaned2], ignore_index=True)
df_final.rename(columns = {'name':'list_name'}, inplace = True)
df_final = df_final.filter(['list_name','track_name'], axis=1)
df_final.head(60)
# Out:
#            list_name                                         track_name
# 0         Throwbacks         Lose Control (feat. Ciara & Fat Man Scoop)
# 1         Throwbacks                                              Toxic
# 2         Throwbacks                                      Crazy In Love
# 3         Throwbacks                                     Rock Your Body
# 4         Throwbacks                                       It Wasn't Me
# 5         Throwbacks                                              Yeah!
# 6         Throwbacks                                             My Boo
# 7         Throwbacks                                            Buttons
# 8         Throwbacks                                        Say My Name
# 9         Throwbacks                     Hey Ya! - Radio Mix / Club Mix
# 10        Throwbacks                                        Promiscuous
# 11        Throwbacks       Right Where You Want Me - Radio Edit Version
# 12        Throwbacks                                     Beautiful Soul
# 13        Throwbacks                                            Leavin'
# 14        Throwbacks                                             Me & U
# 15        Throwbacks                                            Ice Box
# 16        Throwbacks                                          Sk8er Boi
# 17        Throwbacks                                            Run It!
# 18        Throwbacks            Check On It - feat. Bun B and Slim Thug
# 19        Throwbacks                                   Jumpin', Jumpin'
# 20        Throwbacks                                    Soak Up The Sun
# 21        Throwbacks                                 Where Is The Love?
# 22        Throwbacks                                        Stacy's Mom
# 23        Throwbacks                                      Just The Girl
# 24        Throwbacks                                Yo (Excuse Me Miss)
# 25        Throwbacks                                          Year 3000
# 26        Throwbacks                                          Lip Gloss
# 27        Throwbacks                    Everytime We Touch - Radio Edit
# 28        Throwbacks                                        Whatcha Say
# 29        Throwbacks                                   Miss Independent
# 30        Throwbacks                                Party In The U.S.A.
# 31        Throwbacks                                   The Great Escape
# 32        Throwbacks                                             Replay
# 33        Throwbacks                                            Forever
# 34        Throwbacks                               Your Love Is My Drug
# 35        Throwbacks                                             Closer
# 36        Throwbacks                               One Less Lonely Girl
# 37        Throwbacks                                       Paper Planes
# 38        Throwbacks                                     Mr. Brightside
# 39        Throwbacks                               All The Small Things
# 40        Throwbacks                                               Beep
# 41        Throwbacks                                   Somebody To Love
# 42        Throwbacks                                Dirty Little Secret
# 43        Throwbacks                                               Baby
# 44        Throwbacks                                   A Thousand Miles
# 45        Throwbacks                                    Livin on Sunday
# 46        Throwbacks                                      See You Again
# 47        Throwbacks             How Do You Sleep? - Featuring Ludacris
# 48        Throwbacks                                         This Is Me
# 49        Throwbacks                                    My Happy Ending
# 50        Throwbacks                                   Check Yes Juliet
# 51        Throwbacks                                   The Great Escape
# 52  Awesome Playlist                                   Eye of the Tiger
# 53  Awesome Playlist   Libera Me From Hell (Tengen Toppa Gurren Lagann)
# 54  Awesome Playlist                                      Pokémon Theme
# 55  Awesome Playlist         Concerning Hobbits (The Lord of the Rings)
# 56  Awesome Playlist      The Blood of Cuchulainn (The Boondock Saints)
# 57  Awesome Playlist           He's a Pirate (Pirates of the Caribbean)
# 58  Awesome Playlist  Very Bloody Tears (Castlevania II: Simon's Quest)
# 59  Awesome Playlist                         U.N. Owen Was Her? (Remix)

# %%
# Convert df in oneHotEncoded for tracks
from sklearn.preprocessing import LabelBinarizer#LabelBinarizer

jobs_encoder = LabelBinarizer()
jobs_encoder.fit(df_final['track_name'])
#print(jobs_encoder)
transformed = jobs_encoder.transform(df_final['track_name'])
ohe_df = pd.DataFrame(transformed)
jobs_encoder.get_feature_names()
ohe_df.columns = jobs_encoder.get_feature_names()
data_ohe = pd.concat([df_final, ohe_df], axis=1).drop(['track_name'], axis=1)
data_ohe.head(60)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <module>
#       7 transformed = jobs_encoder.transform(df_final['track_name'])
#       8 ohe_df = pd.DataFrame(transformed)
# ----> 9 jobs_encoder.get_feature_names()
#      10 ohe_df.columns = jobs_encoder.get_feature_names()
#      11 data_ohe = pd.concat([df_final, ohe_df], axis=1).drop(['track_name'], axis=1)
#
# AttributeError: 'LabelBinarizer' object has no attribute 'get_feature_names'
